# %% [markdown]
# # Data_Retrieval_and_Plotting

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm
from scipy.stats import linregress
from datetime import datetime

# Import API keys
from api_keys import (weather_api_key, g_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../Output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#To display all the output in a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

#Create a seed --> For testing
np.random.seed(1000)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1600)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#Create a placeholder DF for the extracted data from API calls
weather_DF = pd.DataFrame(columns=['City','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Country', 'Date']) 

#Data to get extracted
summary = ['name', 'coord.lat', 'coord.lon', 'main.temp_max', 'main.humidity', 'clouds.all', 'wind.speed', 'sys.country', 'dt']             

#Parms to pass to the API call
params = {'units': 'imperial',
          'appid' : weather_api_key}

#Iteratively call openweathermap api using python wrapper
print("Beginning Data Retrieval\n\
-----------------------------")
count=0 #Successful queries
for index, city in enumerate(cities):
    try:
        result = owm.get_current(city,**params)
        weather_DF.loc[count] = result(*summary)
        print(f"Processed Record {index} | {city}")
        count+=1
    except:
        print(f"Record {index}: City {city} not found. Skipping...") 
    time.sleep(1) #1 sec delay between API calls
print("-----------------------------\n\
Data Retrieval Complete\n\
-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processed Record 0 | kapaa
# Processed Record 1 | rikitea
# Processed Record 2 | tasiilaq
# Processed Record 3 | puerto ayora
# Processed Record 4 | svetlogorsk
# Processed Record 5 | kaitangata
# Processed Record 6 | albany
# Processed Record 7 | kununurra
# Processed Record 8 | chuy
# Processed Record 9 | belyy yar
# Processed Record 10 | castro
# Processed Record 11 | blackfoot
# Processed Record 12 | camapua
# Processed Record 13 | ushuaia
# Processed Record 14 | north bend
# Processed Record 15 | hobart
# Processed Record 16 | husavik
# Processed Record 17 | ostrovnoy
# Processed Record 18 | klaksvik
# Processed Record 19 | tiarei
# Processed Record 20 | pevek
# Processed Record 21 | vila velha
# Processed Record 22 | parsons
# Processed Record 23 | yulara
# Processed Record 24 | muravlenko
# Processed Record 25 | matay
# Processed Record 26 | hailun
# Processed Record 27 | norman wells
# Processed Record 28 | khatanga
# Processed Record 29 | punta arenas
# Processed Record 30 | east london
# Processed Record 31 | bredasdorp
# Processed Record 32 | ridgecrest
# Processed Record 33 | caravelas
# Processed Record 34 | kautokeino
# Processed Record 35 | namibe
# Processed Record 36 | sumter
# Processed Record 37 | sao domingos do maranhao
# Record 38: City belushya guba not found. Skipping...
# Processed Record 39 | new norfolk
# Processed Record 40 | cape town
# Processed Record 41 | fare
# Processed Record 42 | casambalangan
# Processed Record 43 | saldanha
# Record 44: City anar darreh not found. Skipping...
# Processed Record 45 | port elizabeth
# Processed Record 46 | atuona
# Processed Record 47 | cabo san lucas
# Record 48: City palabuhanratu not found. Skipping...
# Processed Record 49 | san luis
# Processed Record 50 | mataura
# Processed Record 51 | gaoual
# Processed Record 52 | lufilufi
# Processed Record 53 | mahebourg
# Processed Record 54 | sao filipe
# Processed Record 55 | hofn
# Processed Record 56 | troitsko-pechorsk
# Processed Record 57 | saint-philippe
# Processed Record 58 | bambous virieux
# Processed Record 59 | georgetown
# Processed Record 60 | half moon bay
# Processed Record 61 | nikolskoye
# Record 62: City lolua not found. Skipping...
# Processed Record 63 | honiara
# Processed Record 64 | kurumkan
# Processed Record 65 | inawayan
# Processed Record 66 | chokurdakh
# Processed Record 67 | libertador general san martin
# Record 68: City amderma not found. Skipping...
# Processed Record 69 | yellowknife
# Record 70: City kuche not found. Skipping...
# Processed Record 71 | makakilo city
# Record 72: City nguiu not found. Skipping...
# Processed Record 73 | the pas
# Processed Record 74 | laguna
# Processed Record 75 | naze
# Processed Record 76 | kambove
# Processed Record 77 | tiznit
# Processed Record 78 | shimoda
# Processed Record 79 | carnarvon
# Processed Record 80 | goderich
# Processed Record 81 | busselton
# Processed Record 82 | ilulissat
# Processed Record 83 | torbay
# Processed Record 84 | tessalit
# Processed Record 85 | la grande
# Processed Record 86 | bethel
# Processed Record 87 | lalupon
# Record 88: City samusu not found. Skipping...
# Processed Record 89 | kimbe
# Processed Record 90 | chumikan
# Processed Record 91 | esperance
# Processed Record 92 | labuhan
# Processed Record 93 | shahr-e kord
# Record 94: City vaitupu not found. Skipping...
# Processed Record 95 | te anau
# Record 96: City alotau not found. Skipping...
# Processed Record 97 | ponnani
# Processed Record 98 | mackenzie
# Processed Record 99 | vaini
# Processed Record 100 | isangel
# Processed Record 101 | aykhal
# Processed Record 102 | ossora
# Processed Record 103 | cockburn town
# Processed Record 104 | vila do maio
# Processed Record 105 | upernavik
# Processed Record 106 | bondeno
# Processed Record 107 | urusha
# Processed Record 108 | touros
# Processed Record 109 | nouadhibou
# Processed Record 110 | hermanus
# Processed Record 111 | buta
# Record 112: City saleaula not found. Skipping...
# Processed Record 113 | kuruman
# Processed Record 114 | gisborne
# Processed Record 115 | bilibino
# Processed Record 116 | valparaiso
# Processed Record 117 | tiksi
# Processed Record 118 | bluff
# Processed Record 119 | saint george
# Processed Record 120 | katsuura
# Processed Record 121 | ribeira grande
# Processed Record 122 | roald
# Processed Record 123 | tuktoyaktuk
# Processed Record 124 | cherskiy
# Processed Record 125 | hithadhoo
# Record 126: City taolanaro not found. Skipping...
# Processed Record 127 | provideniya
# Processed Record 128 | olafsvik
# Processed Record 129 | nanortalik
# Processed Record 130 | avarua
# Processed Record 131 | souillac
# Processed Record 132 | katangli
# Processed Record 133 | arraial do cabo
# Processed Record 134 | aranos
# Record 135: City tsihombe not found. Skipping...
# Record 136: City attawapiskat not found. Skipping...
# Processed Record 137 | kanker
# Processed Record 138 | qaanaaq
# Processed Record 139 | maragogi
# Processed Record 140 | general roca
# Processed Record 141 | barrow
# Processed Record 142 | udachnyy
# Record 143: City nizhneyansk not found. Skipping...
# Processed Record 144 | jamestown
# Processed Record 145 | stokmarknes
# Processed Record 146 | sur
# Processed Record 147 | vostok
# Processed Record 148 | korla
# Processed Record 149 | okhotsk
# Processed Record 150 | lensk
# Processed Record 151 | port alfred
# Processed Record 152 | san quintin
# Processed Record 153 | asau
# Processed Record 154 | tuatapere
# Processed Record 155 | lorengau
# Processed Record 156 | san patricio
# Processed Record 157 | lebu
# Record 158: City skalistyy not found. Skipping...
# Processed Record 159 | carambei
# Processed Record 160 | elesbao veloso
# Processed Record 161 | vrangel
# Processed Record 162 | lundazi
# Processed Record 163 | sevierville
# Processed Record 164 | necochea
# Processed Record 165 | amga
# Processed Record 166 | porto santo
# Processed Record 167 | cidreira
# Processed Record 168 | kodiak
# Processed Record 169 | itarema
# Processed Record 170 | catuday
# Processed Record 171 | mehamn
# Processed Record 172 | hasaki
# Processed Record 173 | coquimbo
# Processed Record 174 | kavieng
# Processed Record 175 | monrovia
# Processed Record 176 | maniitsoq
# Record 177: City umzimvubu not found. Skipping...
# Processed Record 178 | dikson
# Processed Record 179 | walvis bay
# Processed Record 180 | paamiut
# Processed Record 181 | tahta
# Processed Record 182 | algarrobo
# Processed Record 183 | beloha
# Processed Record 184 | butaritari
# Processed Record 185 | lucapa
# Processed Record 186 | saint-georges
# Record 187: City scottsburgh not found. Skipping...
# Processed Record 188 | ulagan
# Processed Record 189 | los llanos de aridane
# Processed Record 190 | bengkulu
# Processed Record 191 | otradnoye
# Processed Record 192 | espera feliz
# Processed Record 193 | lagoa
# Processed Record 194 | pochutla
# Processed Record 195 | severo-kurilsk
# Processed Record 196 | yining
# Processed Record 197 | tymovskoye
# Processed Record 198 | port hedland
# Processed Record 199 | pacific grove
# Processed Record 200 | chicla
# Processed Record 201 | andenes
# Processed Record 202 | manali
# Processed Record 203 | tura
# Record 204: City sentyabrskiy not found. Skipping...
# Record 205: City marcona not found. Skipping...
# Processed Record 206 | nagato
# Record 207: City grand river south east not found. Skipping...
# Record 208: City rolim de moura not found. Skipping...
# Processed Record 209 | miraflores
# Processed Record 210 | hobyo
# Processed Record 211 | road town
# Processed Record 212 | mar del plata
# Processed Record 213 | antofagasta
# Processed Record 214 | longuenesse
# Processed Record 215 | saint-ambroise
# Processed Record 216 | finale ligure
# Processed Record 217 | hilo
# Processed Record 218 | genk
# Processed Record 219 | rio grande
# Processed Record 220 | stege
# Processed Record 221 | vozhega
# Processed Record 222 | victoria
# Processed Record 223 | diamantino
# Processed Record 224 | kruisfontein
# Processed Record 225 | dong hoi
# Processed Record 226 | bilma
# Processed Record 227 | chute-aux-outardes
# Processed Record 228 | kalabo
# Processed Record 229 | ixtapa
# Processed Record 230 | san policarpo
# Processed Record 231 | oranjemund
# Processed Record 232 | vila
# Processed Record 233 | uray
# Processed Record 234 | nalut
# Processed Record 235 | marsa matruh
# Processed Record 236 | praia
# Processed Record 237 | ilam
# Processed Record 238 | fairbanks
# Processed Record 239 | pokrovsk
# Processed Record 240 | rosarito
# Processed Record 241 | kondinskoye
# Record 242: City karakendzha not found. Skipping...
# Processed Record 243 | saskylakh
# Processed Record 244 | itai
# Processed Record 245 | kasongo-lunda
# Processed Record 246 | price
# Processed Record 247 | port hardy
# Processed Record 248 | koygorodok
# Processed Record 249 | leningradskiy
# Processed Record 250 | sungairaya
# Processed Record 251 | bundaberg
# Processed Record 252 | mahanoro
# Processed Record 253 | mount isa
# Record 254: City illoqqortoormiut not found. Skipping...
# Processed Record 255 | batagay-alyta
# Processed Record 256 | gao
# Record 257: City bolshegrivskoye not found. Skipping...
# Record 258: City burkhala not found. Skipping...
# Processed Record 259 | otane
# Processed Record 260 | vestmanna
# Processed Record 261 | dunedin
# Processed Record 262 | longyearbyen
# Processed Record 263 | clyde river
# Processed Record 264 | tabou
# Processed Record 265 | kangaatsiaq
# Processed Record 266 | odienne
# Processed Record 267 | verkh-usugli
# Processed Record 268 | san lorenzo
# Processed Record 269 | sandviken
# Processed Record 270 | geraldton
# Processed Record 271 | parrita
# Processed Record 272 | constitucion
# Processed Record 273 | raudeberg
# Processed Record 274 | severodvinsk
# Processed Record 275 | minot
# Processed Record 276 | vao
# Processed Record 277 | padang
# Processed Record 278 | iqaluit
# Processed Record 279 | deputatskiy
# Processed Record 280 | mattru
# Record 281: City barentsburg not found. Skipping...
# Processed Record 282 | milan
# Processed Record 283 | matai
# Processed Record 284 | anaco
# Processed Record 285 | ponta delgada
# Record 286: City warqla not found. Skipping...
# Processed Record 287 | rawson
# Processed Record 288 | kahului
# Processed Record 289 | cobija
# Processed Record 290 | slave lake
# Processed Record 291 | constantine
# Processed Record 292 | shetpe
# Processed Record 293 | piney green
# Processed Record 294 | san cristobal
# Processed Record 295 | petrovskoye
# Processed Record 296 | itacoatiara
# Processed Record 297 | ayorou
# Processed Record 298 | yoichi
# Processed Record 299 | roros
# Processed Record 300 | izberbash
# Processed Record 301 | lazaro cardenas
# Processed Record 302 | tuy hoa
# Processed Record 303 | riyadh
# Processed Record 304 | airai
# Processed Record 305 | champerico
# Processed Record 306 | mauguio
# Processed Record 307 | yumen
# Processed Record 308 | esil
# Processed Record 309 | hamilton
# Processed Record 310 | pangnirtung
# Processed Record 311 | ponta do sol
# Processed Record 312 | kavaratti
# Processed Record 313 | iranshahr
# Processed Record 314 | coihaique
# Processed Record 315 | trogir
# Processed Record 316 | farim
# Processed Record 317 | dutlwe
# Processed Record 318 | baiyin
# Processed Record 319 | teyateyaneng
# Processed Record 320 | sladkovo
# Record 321: City jabiru not found. Skipping...
# Record 322: City ituni not found. Skipping...
# Processed Record 323 | lokachi
# Processed Record 324 | cap malheureux
# Processed Record 325 | berlevag
# Processed Record 326 | akyab
# Processed Record 327 | belmonte
# Processed Record 328 | zabol
# Processed Record 329 | abu samrah
# Processed Record 330 | kawalu
# Processed Record 331 | coolum beach
# Processed Record 332 | beira
# Processed Record 333 | iki-burul
# Processed Record 334 | mecca
# Processed Record 335 | fraserburgh
# Record 336: City sorvag not found. Skipping...
# Processed Record 337 | hwange
# Processed Record 338 | thompson
# Processed Record 339 | bambanglipuro
# Processed Record 340 | chicama
# Processed Record 341 | samarai
# Processed Record 342 | vanavara
# Processed Record 343 | flin flon
# Processed Record 344 | alekseyevka
# Processed Record 345 | rio claro
# Processed Record 346 | basudebpur
# Processed Record 347 | paratinga
# Processed Record 348 | douglas
# Processed Record 349 | bonavista
# Processed Record 350 | parauna
# Processed Record 351 | batetskiy
# Processed Record 352 | avera
# Processed Record 353 | richards bay
# Processed Record 354 | buluang
# Processed Record 355 | ancud
# Processed Record 356 | hualmay
# Processed Record 357 | yar-sale
# Processed Record 358 | luxor
# Processed Record 359 | biltine
# Processed Record 360 | seoul
# Processed Record 361 | sorong
# Processed Record 362 | mount pleasant
# Processed Record 363 | acton vale
# Processed Record 364 | quzhou
# Processed Record 365 | kati
# Processed Record 366 | miri
# Processed Record 367 | biak
# Record 368: City utiroa not found. Skipping...
# Processed Record 369 | pendleton
# Processed Record 370 | pisco
# Processed Record 371 | daru
# Record 372: City kleck not found. Skipping...
# Processed Record 373 | slonim
# Record 374: City mys shmidta not found. Skipping...
# Processed Record 375 | kutulik
# Processed Record 376 | dingle
# Processed Record 377 | chililabombwe
# Processed Record 378 | sal rei
# Processed Record 379 | kaeo
# Processed Record 380 | pangani
# Processed Record 381 | hashimoto
# Processed Record 382 | nizwa
# Processed Record 383 | dicabisagan
# Processed Record 384 | port blair
# Processed Record 385 | ulaangom
# Processed Record 386 | alta
# Processed Record 387 | khandbari
# Processed Record 388 | ajuchitlan
# Record 389: City kamenskoye not found. Skipping...
# Processed Record 390 | yuncheng
# Processed Record 391 | opuwo
# Processed Record 392 | noumea
# Processed Record 393 | ashland
# Processed Record 394 | domoni
# Processed Record 395 | solvychegodsk
# Processed Record 396 | leninsk
# Processed Record 397 | meridian
# Processed Record 398 | talnakh
# Processed Record 399 | grao mogol
# Processed Record 400 | khilok
# Processed Record 401 | ust-karsk
# Processed Record 402 | inirida
# Processed Record 403 | zhigansk
# Processed Record 404 | prestea
# Processed Record 405 | lohr
# Processed Record 406 | grand gaube
# Processed Record 407 | kutum
# Processed Record 408 | sambava
# Processed Record 409 | hay river
# Processed Record 410 | key west
# Processed Record 411 | san jose de guanipa
# Processed Record 412 | mata
# Processed Record 413 | qaqortoq
# Processed Record 414 | suclayin
# Record 415: City miranorte not found. Skipping...
# Processed Record 416 | meulaboh
# Processed Record 417 | riachao das neves
# Processed Record 418 | morant bay
# Processed Record 419 | oistins
# Processed Record 420 | libreville
# Processed Record 421 | itaituba
# Processed Record 422 | quelimane
# Processed Record 423 | eureka
# Processed Record 424 | nosy varika
# Processed Record 425 | antsohihy
# Processed Record 426 | burns lake
# Processed Record 427 | hebi
# Record 428: City meyungs not found. Skipping...
# Processed Record 429 | cayenne
# Processed Record 430 | batsfjord
# Processed Record 431 | muhos
# Processed Record 432 | ugoofaaru
# Processed Record 433 | joshimath
# Processed Record 434 | vardo
# Processed Record 435 | azangaro
# Processed Record 436 | grand-lahou
# Processed Record 437 | anadyr
# Processed Record 438 | arman
# Processed Record 439 | alekseyevsk
# Processed Record 440 | mao
# Processed Record 441 | chebarkul
# Processed Record 442 | namatanai
# Processed Record 443 | sobolevo
# Processed Record 444 | lasa
# Processed Record 445 | acapulco
# Processed Record 446 | palhoca
# Processed Record 447 | luderitz
# Processed Record 448 | puri
# Processed Record 449 | aswan
# Processed Record 450 | faanui
# Processed Record 451 | bereda
# Processed Record 452 | port lincoln
# Processed Record 453 | cedeno
# Processed Record 454 | komsomolskiy
# Processed Record 455 | saint anthony
# Processed Record 456 | pilar
# Processed Record 457 | beringovskiy
# Processed Record 458 | tevaitoa
# Record 459: City sansai not found. Skipping...
# Processed Record 460 | bathsheba
# Processed Record 461 | brive-la-gaillarde
# Processed Record 462 | ola
# Processed Record 463 | kiama
# Processed Record 464 | alofi
# Processed Record 465 | quatre cocos
# Processed Record 466 | yubari
# Processed Record 467 | hervey bay
# Processed Record 468 | zary
# Processed Record 469 | nizhnevartovsk
# Processed Record 470 | norfolk
# Processed Record 471 | seymchan
# Processed Record 472 | nuevo progreso
# Processed Record 473 | revda
# Processed Record 474 | kollam
# Record 475: City ngukurr not found. Skipping...
# Processed Record 476 | henderson
# Processed Record 477 | wanning
# Record 478: City acuna not found. Skipping...
# Processed Record 479 | aripuana
# Processed Record 480 | nizhniy odes
# Record 481: City ondorhaan not found. Skipping...
# Processed Record 482 | gayny
# Processed Record 483 | petropavlovsk-kamchatskiy
# Processed Record 484 | fortuna
# Processed Record 485 | marquette
# Processed Record 486 | saurimo
# Processed Record 487 | volksrust
# Processed Record 488 | dufftown
# Processed Record 489 | bairiki
# Processed Record 490 | krasnoselkup
# Processed Record 491 | le marin
# Processed Record 492 | muros
# Processed Record 493 | turinsk
# Processed Record 494 | mabaruma
# Processed Record 495 | sistranda
# Processed Record 496 | yeniseysk
# Processed Record 497 | narasannapeta
# Processed Record 498 | abeche
# Processed Record 499 | atar
# Processed Record 500 | manaure
# Processed Record 501 | anuchino
# Processed Record 502 | ntungamo
# Processed Record 503 | khash
# Processed Record 504 | copiapo
# Processed Record 505 | sungaipenuh
# Record 506: City bur gabo not found. Skipping...
# Processed Record 507 | artigas
# Processed Record 508 | hosakote
# Processed Record 509 | lompoc
# Processed Record 510 | matagami
# Processed Record 511 | stornoway
# Processed Record 512 | thornhill
# Processed Record 513 | smithers
# Processed Record 514 | swift current
# Processed Record 515 | curitibanos
# Processed Record 516 | maldonado
# Processed Record 517 | saint-augustin
# Processed Record 518 | kandrian
# Processed Record 519 | bandarbeyla
# Processed Record 520 | sitka
# Processed Record 521 | roebourne
# Processed Record 522 | lere
# Processed Record 523 | urumqi
# Processed Record 524 | lahaina
# Processed Record 525 | pahrump
# Processed Record 526 | falun
# Processed Record 527 | nome
# Processed Record 528 | santa lucia
# Processed Record 529 | rozivka
# Processed Record 530 | marawi
# Record 531: City urozhayne not found. Skipping...
# Processed Record 532 | ambunti
# Processed Record 533 | torquay
# Processed Record 534 | abu dhabi
# Processed Record 535 | sabang
# Processed Record 536 | narsaq
# Processed Record 537 | ikalamavony
# Processed Record 538 | kupang
# Processed Record 539 | fort abbas
# Processed Record 540 | ban tak
# Record 541: City cagayan de tawi-tawi not found. Skipping...
# Processed Record 542 | koumac
# Processed Record 543 | pozo colorado
# Processed Record 544 | bolu
# Processed Record 545 | ivanava
# Processed Record 546 | norilsk
# Processed Record 547 | ambilobe
# Record 548: City barawe not found. Skipping...
# Processed Record 549 | tucupita
# Processed Record 550 | ngunguru
# Processed Record 551 | nishihara
# Processed Record 552 | manoel urbano
# Processed Record 553 | bud
# Processed Record 554 | baft
# Processed Record 555 | kota kinabalu
# Processed Record 556 | sterling
# Processed Record 557 | lodja
# Processed Record 558 | herat
# Processed Record 559 | tyrma
# Processed Record 560 | san juan
# Processed Record 561 | keflavik
# Processed Record 562 | olinda
# Processed Record 563 | roseburg
# Processed Record 564 | okato
# Processed Record 565 | moelv
# Processed Record 566 | harlingen
# Processed Record 567 | sept-iles
# Processed Record 568 | dauphin
# Processed Record 569 | kamina
# Processed Record 570 | port augusta
# Record 571: City tabiauea not found. Skipping...
# Record 572: City chagda not found. Skipping...
# Record 573: City formoso do araguaia not found. Skipping...
# Processed Record 574 | mugumu
# Processed Record 575 | zhezkazgan
# Record 576: City yialos not found. Skipping...
# Processed Record 577 | katherine
# Processed Record 578 | halle
# Processed Record 579 | sicamous
# Processed Record 580 | hambantota
# Processed Record 581 | zinder
# Processed Record 582 | maningrida
# Processed Record 583 | haines junction
# Processed Record 584 | gamba
# Record 585: City yanan not found. Skipping...
# Processed Record 586 | zhob
# Processed Record 587 | grindavik
# Processed Record 588 | chengde
# Processed Record 589 | rabat
# Processed Record 590 | zhengjiatun
# Processed Record 591 | pasinler
# Processed Record 592 | santa maria
# Processed Record 593 | havre
# Processed Record 594 | itoman
# Processed Record 595 | gurupa
# Processed Record 596 | sola
# Processed Record 597 | guerrero negro
# Processed Record 598 | umm kaddadah
# Processed Record 599 | taoudenni
# Processed Record 600 | binga
# Record 601: City karakose not found. Skipping...
# Processed Record 602 | centralia
# Processed Record 603 | vestmannaeyjar
# Processed Record 604 | ahipara
# Processed Record 605 | havelock
# Processed Record 606 | taltal
# Processed Record 607 | baltasi
# Processed Record 608 | conakry
# Processed Record 609 | salalah
# Processed Record 610 | waipawa
# Processed Record 611 | winona
# Processed Record 612 | abonnema
# Processed Record 613 | palmer
# Processed Record 614 | vigrestad
# Processed Record 615 | bogalusa
# Processed Record 616 | semey
# Processed Record 617 | shizukuishi
# Processed Record 618 | juli
# Processed Record 619 | acarau
# Processed Record 620 | san vicente
# Processed Record 621 | lenauheim
# Processed Record 622 | terrace
# Processed Record 623 | marga
# Processed Record 624 | shenjiamen
# Processed Record 625 | villaviciosa
# Processed Record 626 | lysyanka
# Processed Record 627 | luwingu
# Processed Record 628 | hyeres
# Processed Record 629 | katobu
# Processed Record 630 | stromness
# Processed Record 631 | whyalla
# Processed Record 632 | macusani
# Processed Record 633 | lae
# Processed Record 634 | tautira
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_DF.info()
weather_DF.to_csv('../Output/cities_weather.csv', index=False, encoding='utf-8')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 584 entries, 0 to 583
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        584 non-null    object
#  1   Lat         584 non-null    float64
#  2   Lng         584 non-null    float64
#  3   Max Temp    584 non-null    float64
#  4   Humidity    584 non-null    object
#  5   Cloudiness  584 non-null    object
#  6   Wind Speed  584 non-null    float64
#  7   Country     584 non-null    object
#  8   Date        584 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 45.6+ KB

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_DF[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed']] = weather_DF[['Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
       'Wind Speed']].astype('float')

# %%
weather_DF.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000
# mean    20.253373   15.857808   68.678116   70.635274   47.946918    7.499572
# std     33.691222   89.953690   14.156463   20.402440   37.553606    5.236034
# min    -54.800000 -175.200000   30.200000   10.000000    0.000000    0.160000
# 25%     -9.615000  -59.592500   59.000000   59.000000    9.000000    3.360000
# 50%     22.785000   18.770000   69.800000   74.000000   44.000000    6.035000
# 75%     50.220000   91.560000   80.010000   86.000000   87.000000   10.290000
# max     78.220000  179.320000  100.510000  100.000000  100.000000   30.290000

# %%
#  Get the indices of cities that have humidity over 100%.

#remove the cities where the humidity > 100%
indices_above_100 = weather_DF[weather_DF['Humidity']>100].index
indices_above_100
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_DF.drop(indices_above_100, axis=0) #By default "inplace=False"

# %%
# Extract relevant fields from the data frame


#Keeping ['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness','Wind Speed', 'Country']
clean_city_data = clean_city_data[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness','Wind Speed']]
# Export the City_Data into a csv
clean_city_data.to_csv('../Output/cleaned_cities_weather.csv', index=False, encoding='utf-8')

# %%
clean_city_data.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa      US  22.08 -159.32     82.40      74.0        20.0
# 1       Rikitea      PF -23.12 -134.97     70.59      78.0         3.0
# 2      Tasiilaq      GL  65.61  -37.64     41.00      93.0       100.0
# 3  Puerto Ayora      EC  -0.74  -90.35     68.00      88.0        55.0
# 4  Forsytheganj      BY  52.63   29.73     64.87      91.0        85.0
#
#    Wind Speed
# 0       21.92
# 1       19.46
# 2        5.82
# 3        3.00
# 4        4.72

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# %matplotlib inline
from matplotlib import style
plt.style.available
# Out:
# ['_classic_test_patch',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
plt.style.use('seaborn')

# %%
#The date of retrieving the data
utc_date = weather_DF['Date'].map(lambda x: datetime.utcfromtimestamp(int(x)).strftime('%d/%m/%Y')).unique()[0]

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax1 = plt.subplots(figsize=(8,8))
_ = clean_city_data.plot(x='Lat', 
                           y='Max Temp',
                           kind='scatter',
                           grid=True,
                           edgecolor='k',
                           s=30,
                           fontsize=18,
                           ylim=(min(clean_city_data['Max Temp'])-5, max(clean_city_data['Max Temp'])+5),
                           ax=ax1
                          )            


_=ax1.set_xlabel('Latitude', fontsize=18)
_=ax1.set_facecolor('lightcoral')
_=ax1.set_ylabel('Max Temperature $^\circ$(F)', fontsize=18)
_=ax1.set_title(f"City Latitude vs. Max Temperature ({utc_date})", fontsize=20)
plt.tight_layout()
plt.savefig('../Resources/assets/images/plot1.png',facecolor='white',edgecolor='white', bbox_inches='tight')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax2 = plt.subplots(figsize=(8,8))
ax2 = clean_city_data.plot(x='Lat', 
                           y='Humidity',
                           kind='scatter',
                           grid=True,
                           edgecolor='k',
                           s=30,
                           ylim=(min(clean_city_data['Humidity'])-5, max(clean_city_data['Humidity'])+5),
                           fontsize=18,
                           ax=ax2
                          )            


_=ax2.set_xlabel('Latitude', fontsize=18)
_=ax2.set_ylabel('Humidity (%)', fontsize=18)
_=ax2.set_facecolor('lightcoral')
_=ax2.set_title(f"City Latitude vs. Humidity ({utc_date})", fontsize=20)
plt.tight_layout()
plt.savefig('../Resources/assets/images/plot2.png',facecolor='white',edgecolor='white', bbox_inches='tight')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax3 = plt.subplots(figsize=(8,8))
_ = clean_city_data.plot(x='Lat', 
                           y='Cloudiness',
                           kind='scatter',
                           grid=True,
                           edgecolor='k',
                           s=30,
                           ylim=(min(clean_city_data['Cloudiness'])-5, max(clean_city_data['Cloudiness'])+5),
                           fontsize=18,
                           ax=ax3
                          )            


_=ax3.set_xlabel('Latitude', fontsize=18)
_=ax3.set_ylabel('Cloudiness (%)', fontsize=18)
_=ax3.set_title(f"City Latitude vs. Cloudiness ({utc_date})", fontsize=20)
_=ax3.set_facecolor('lightcoral')

plt.tight_layout()
plt.savefig('../Resources/assets/images/plot3.png',facecolor='white',edgecolor='white', bbox_inches='tight')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax4 = plt.subplots(figsize=(8,8))
_ = clean_city_data.plot(x='Lat', 
                           y='Wind Speed',
                           kind='scatter',
                           grid=True,
                           edgecolor='k',
                           s=30,
                           ylim=(min(clean_city_data['Wind Speed'])-2, max(clean_city_data['Wind Speed'])+2),
                           fontsize=18,
                           ax=ax4
                          )            


_=ax4.set_xlabel('Latitude', fontsize=18)
_=ax4.set_ylabel('Wind Speed (mph)', fontsize=18)
_=ax4.set_title(f"City Latitude vs. Wind Speed ({utc_date})", fontsize=20)
_=ax4.set_facecolor('lightcoral')
plt.tight_layout()
plt.savefig('../Resources/assets/images/plot4.png', facecolor='white',edgecolor='white', bbox_inches='tight')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linregress_plots(DF, xl, yl, xlabel='Latitude', ylabel='', title='', figname='plot.png'):

    m, c, r, p, _ = linregress(DF[xl], DF[yl])
    print(f"The r-squared is: {r**2}")
    

    #Create a new figure
    fig, ax =plt.subplots(figsize=(6,6))

    #Scatter plot
    _ = DF.plot(x=xl, 
              y=yl,
              kind='scatter',
              s=30,
              title=title,
              ylim = (min(DF[yl])-5, max(DF[yl]+15)),
              ax=ax
              )            

    _=ax.set_xlabel(xlabel)
    _=ax.set_ylabel(ylabel)

    #Regression Line
    y=m*DF[xl] + c
    _=ax.plot(DF[xl], y, 'purple', linewidth=2)
    
    
    pos=((0.15, 0.2) if m<=-0.4 else ((0.15, 0.75) if m>0.4 else (0.5, 0.85))) #Annotate position
    
    #A way to dynamically finds the number of decimal positions if there is avery small value Eg:- 0.000000067
    #We don't want to denote it as 0.00
    val = m*100
    digits = 2
    while int(val)==0:
        val*=10
        digits+=1
    
    s = "{:."+f"{digits}"+"f}"
    format_string = "y = "+s+"x + {:.2f}"
    linear_eqn = format_string.format(m, c)
    _=ax.annotate(linear_eqn,
            xy=pos, xycoords='figure fraction', fontsize=15, color='purple')

    
    _=ax.set_facecolor('#FFD1C1')
    plt.tight_layout()
    plt.savefig(f"../Resources/assets/images/{figname}",facecolor='white',edgecolor='white', bbox_inches='tight')
    _=plt.show()
    
    return(r, p)

#This function returns the r value, and p value
#r value: Pearson Correlation Coefficient
#p value: is a measure of the significance of the gradient. If p value is < 0.01 (Significance level),
#it means that, we cannot independent variable affects dependant variable

# %%
# Create Northern and Southern Hemisphere DataFrames
NHS = clean_city_data[clean_city_data['Lat']>=0]#Northern Hemisphere (Keeping equator part of NHS; tie breaking)
SHS = clean_city_data[clean_city_data['Lat']<0]#Southern Hemisphere

NHS.info()
SHS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394 entries, 0 to 579
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        394 non-null    object
#  1   Country     394 non-null    object
#  2   Lat         394 non-null    float64
#  3   Lng         394 non-null    float64
#  4   Max Temp    394 non-null    float64
#  5   Humidity    394 non-null    float64
#  6   Cloudiness  394 non-null    float64
#  7   Wind Speed  394 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 27.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 1 to 583
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        190 non-null    object
#  1   Country     190 non-null    object
#  2   Lat         190 non-null    float64
#  3   Lng         190 non-null    float64
#  4   Max Temp    190 non-null    float64
#  5   Humidity    190 non-null    float64
#  6   Cloudiness  190 non-null    float64
#  7   Wind Speed  190 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 13.4+ KB

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linregress_plots(NHS, 'Lat', 'Max Temp', ylabel='Max Temperature (F)', title=f"Northern Hemi Sphere: \nCity Latitude vs. Max Temperature ({utc_date})", figname='plot5.png')
# Out:
# The r-squared is: 0.4697918530320439
# (-0.6854136364503145, 5.745472698431099e-56)

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linregress_plots(SHS, 'Lat', 'Max Temp', ylabel='Max Temperature (F)', title=f"Southern Hemi Sphere: \nCity Latitude vs. Max Temperature ({utc_date})", figname='plot6.png')
# Out:
# The r-squared is: 0.4299775899738912
# (0.6557267647228464, 9.96374057157756e-25)

# %% [markdown]
# * Temperature depends on the distance from equator.
#     * Please observe the p value of the linear regression estimator << 0. This means that slope is NOT zero
#     * In both hemispheres, a high correlation between latitude and temperature
#     * We can observe a pattern in scatter plot also
# * As we move towards equator, temperature increases in both sides of the hemisphere
# * From the data, it looks like, temperatures at cities equidistant from equator in both the sides might not be same.
#     * For instance,
#         * At latitude +30, temperature is approximated as -0.45*30+89.53=76.03 F
#         * At latitude -30, temperature is approximated as 0.75*-30+78.58 = 56.08F.
#     * This is because, most of the northern hemisphere is land and most of the southern hemisphere is ocean and ocean is likely to be colder

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linregress_plots(NHS, 'Lat', 'Humidity', ylabel='Humidity (%)', title=f"Northern Hemi Sphere: \nCity Latitude vs. Humidity ({utc_date})", figname='plot7.png')
# Out:
# The r-squared is: 0.0012319789008795276
# (-0.035099556989790164, 0.4872390626351867)

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linregress_plots(SHS, 'Lat', 'Humidity', ylabel='Humidity (%)', title=f"Southern Hemi Sphere: \nCity Latitude vs. Humidity ({utc_date})", figname='plot8.png')
# Out:
# The r-squared is: 0.0019112252578502972
# (-0.043717562350276316, 0.5492296395804125)

# %% [markdown]
# * Humidity(%) doesn't correlate with the distance from equator.
#     * Please observe that p value of the linear regression estimator >> 0 (>significance level(typically 0.05)). This means that WE CANNOT say that slope is NOT zero.
#     * In both hemispheres, a near to ZERO correlation between latitude and humidity.
#     * No pattern in scatter plot.
# * At the time of data is taken, humidity is centred around almost the same value in both hemispheres.
#     * In northern hemisphere, most of the cities are having humidity around 72%.
#     * In southern hemisphere, most of the cities are having humidity around 70%.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linregress_plots(NHS, 'Lat', 'Cloudiness', ylabel='Cloudiness (%)', title=f"Northern Hemi Sphere: \nCity Latitude vs. Cloudiness ({utc_date})", figname='plot9.png')
# Out:
# The r-squared is: 0.0017796273938309912
# (-0.04218563018174543, 0.40367707913827977)

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linregress_plots(SHS, 'Lat', 'Cloudiness', ylabel='Cloudiness (%)', title=f"Southern Hemi Sphere: \nCity Latitude vs. Cloudiness ({utc_date})", figname='plot10.png')
# Out:
# The r-squared is: 0.0031020995032241855
# (0.0556964945326381, 0.4453144726323204)

# %% [markdown]
# * Cloudiness(%) doesn't correlate with the distance from equator.
#     * Please observe that p value of the linear regression estimator > significance level (typically 0.05). This means that WE CANNOT say that slope is NOT zero.
#     * In both hemispheres, a weak correlation between latitude and cloudiness.
#     * No pattern in scatter plot.
# * Cloudiness is centered around different values in both hemispheres.
#     * Northern hemisphere has average cloudiness around 54%.
#     * Southern hemisphere has average cloudiness around 46%.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linregress_plots(NHS, 'Lat', 'Wind Speed', ylabel='Wind Speed (mph)', title=f"Northern Hemi Sphere: \nCity Latitude vs. Wind Speed ({utc_date})", figname='plot11.png')
# Out:
# The r-squared is: 0.003403971027988506
# (0.058343560295790194, 0.24793013554158752)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linregress_plots(SHS, 'Lat', 'Wind Speed', ylabel='Wind Speed (mph)', title=f"Southern Hemi Sphere: \nCity Latitude vs. Wind Speed ({utc_date})", figname='plot12.png')
# Out:
# The r-squared is: 0.0007087795442560795
# (-0.0266229138949154, 0.7153991446033752)

# %% [markdown]
# * Windspeed doesn't correlate with the distance from equator.
#     * Please observe that p value of the linear regression estimator > significance level (typically 0.05).
#         This means that WE CANNOT say that slope is NOT zero.
#     * In both hemispheres, a weak correlation between latitude and Windspeed.
#     * No pattern in scatter plot.
# * At the time of data is taken, windspeed is centred around almost the same value in both hemispheres.
#     * Northern hemisphere has average windspeed around 6.9 mph.
#     * Southern hemisphere has average windspeed around 7.1 mph.

# %% [markdown]
# ## Convert DF to HTML

# %%
clean_city_data.to_html('../Resources/assets/tables/data.html')
